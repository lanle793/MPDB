# %%
from fastai.vision.all import *
from os import path

# %%
path = '../data/'

train_df = pd.read_csv(path + 'train.csv')
train_df.head()
# Out:
#        id       genres
# 0   71139       Comedy
# 1   73330       Comedy
# 2   53693  Documentary
# 3  121140       Horror
# 4   45090    Adventure

# %%
def get_x(r):
    return path + 'train_data/' + r['id'].astype(str) + '.jpg'

def get_y(r):
    return r['genres']

dblock = DataBlock(blocks=(ImageBlock, CategoryBlock),
                   get_x = get_x, 
                   get_y = get_y,
                   item_tfms = RandomResizedCrop(128, min_scale = 0.35),
                   batch_tfms=aug_transforms())

# %%
dls = dblock.dataloaders(train_df)
dls.show_batch(nrows=1, ncols=3)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
model = xresnet50(n_out=dls.c)
learn = Learner(dls, model, metrics=accuracy)
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=8.317637839354575e-05, lr_steep=0.2089296132326126)

# %%
learn.fit_one_cycle(10, 7e-4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 3:44:27<24:56]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.117845</td>
#       <td>2.224000</td>
#       <td>0.276646</td>
#       <td>23:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.136233</td>
#       <td>2.208920</td>
#       <td>0.241564</td>
#       <td>23:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.072919</td>
#       <td>2.082505</td>
#       <td>0.279653</td>
#       <td>25:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.040025</td>
#       <td>2.073674</td>
#       <td>0.270297</td>
#       <td>26:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.014609</td>
#       <td>2.075564</td>
#       <td>0.265620</td>
#       <td>27:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.984890</td>
#       <td>1.990595</td>
#       <td>0.297695</td>
#       <td>23:33</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.961325</td>
#       <td>1.971579</td>
#       <td>0.300368</td>
#       <td>24:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.909018</td>
#       <td>1.979186</td>
#       <td>0.304043</td>
#       <td>23:55</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.905383</td>
#       <td>1.950388</td>
#       <td>0.307718</td>
#       <td>26:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='107' class='' max='187' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       57.22% [107/187 12:58<09:42 1.8875]
#     </div>

# %%
learn.show_results()

# %%
learn.export('single_genre_predictor_fastai.pkl')

# %% [markdown]
# Reference:
# https://github.com/fastai/fastbook/blob/master/05_pet_breeds.ipynb
